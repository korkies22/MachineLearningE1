# %%
#Importar librerías
import math
import csv
import numpy as np
import pandas as pd
from sklearn.neural_network  import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from random import randrange
from IPython.display import HTML, display

# %%
#Leer el archivo con los datos
y = []
x=[]
with open('./data/xtrain.txt') as f:
    for line in f:
        x.append([float(i) for i in line.split()])
with open('./data/ytrain.txt') as g:
    for line in g:
        y.append([float(i) for i in line.split()])

# %% [markdown]
# Si se utilizan 1000 datos para realizar las validaciones y evaluaciones del modelo respectivamente, entonces la confianza con la que el error estimado esté máximo a 0.1 de diferencia del error real es de:

# %%
#La confianza se obtiene de acuerdo a la cuotas de
confianza=1-2*math.exp(-2*0.05**2*1100)
print(confianza)
# Out:
# 0.9918264571230718

# %% [markdown]
# Como se puede observar esta confianza es ligeramente superior al 99%. Lo cual significa que usar 1100 datos es un buen estimativo para estar máximo a 0.05 del error.
# Se parten los datos en entrenamiento y test

# %%
#Se divide el archivo para entrenamiento y test. 
#Se reserven 600 datos para test de acuerdo con la confianza anteriormente mencionada
xTrain, xValidation, yTrain, yValidation = train_test_split(x, y, test_size = 1100, random_state = 0)
print(len(yTrain))
# Out:
# 9900

# %%
def center(X):
    newX = X - np.mean(X, axis = 0)
    return newX
def whiten(X):
    newX = center(X)
    cov = X.T.dot(X)/float(X.shape[0])
    # Calculate the eigenvalues and eigenvectors of the covariance matrix
    eigVals, eigVecs = np.linalg.eig(cov)
    # Apply the eigenvectors to X
    decorrelated = X.dot(eigVecs)
    # Rescale the decorrelated data
    whitened = decorrelated / np.sqrt(eigVals + 1e-5)
    return whitened

# %%
scaler = preprocessing.StandardScaler()
# Fit your data on the scaler object
x1 = scaler.fit_transform(xTrain)

x2=[]
x2=whiten(np.array(xTrain))
xs=[xTrain,x1,x2]

# %%
#Función para entrenar una red de una sola capa escondida, 
#la entrena y concatena tanto la red como el error a respectivos arreglos
def trainNetwork(n,xTrainT,yTrainT,activationF):
    #Se escoge relu puesto que esta fue la que mejor dió en las pruebas realizadas
    clf = MLPClassifier(solver='lbfgs',batch_size=1, alpha=0,hidden_layer_sizes=(n),activation=activationF, max_iter=500, random_state=1)
    clf.fit(xTrainT, yTrainT)   
    return [clf,clf.score(xValidation, yValidation)]

# %%
def trainActiv(activation):
    #Se itera por número de capas y número de neuronas, desde una capa hasta 7, y desde una neurona por capa hasta 30
    errors=[]
    neurons=[]
    for i in range(len(xs)):
        #Se crean arreglos temporales, cada uno corresponde a un número de capas
        errorsTemp=[None]
        neuronsTemp=[]
        for j in range(1, 50):
            #Se almacenan los resultados en los arreglos
            neuron=trainNetwork(j,xs[i],yTrain,activation)
            neuronsTemp.append(neuron[0])
            errorsTemp.append(neuron[1])
        #Al final se concatenan estos arreglos temporales a los globales
        errors.append(errorsTemp)
        neurons.append(neuronsTemp)
    #Se convierten a np
    errors=np.array(errors)
    neurons=np.array(neurons)
    return [errors,neurons]

# %%
#Se crean arreglos vacíos para almacenar los errores obtenidos de clasificación y las redes neuronales 
train1=trainActiv('relu')
train2=trainActiv('logistic')
train3=trainActiv('tanh')
train4=trainActiv('identity')
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:921: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# D:\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:921: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# D:\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:921: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
#Algoritmo para encontrar los índices del elemento más grande de un arreglo 2D, en caso de varias ocurrencias retorna la última
def findMaxIndexes(arr):
    maxC=0
    maxIndex=[-1,-1]
    for i in range(len(arr)):
        for j in range(len(arr[0])):
            if arr[i][j] is not None and arr[i][j]>=maxC:
                maxIndex=[i,j]
                maxC=arr[i][j]
    return maxIndex

# %%
#Se utiliza el algoritmo anterior para encontrar la red de mejor resultado
[ind1,ind2]=findMaxIndexes(train1[0])
print(ind1,ind2)
print(train1[0][ind1][ind2])

[ind1,ind2]=findMaxIndexes(train2[0])
print(ind1,ind2)
print(train2[0][ind1][ind2])

[ind1,ind2]=findMaxIndexes(train3[0])
print(ind1,ind2)
print(train3[0][ind1][ind2])

[ind1,ind2]=findMaxIndexes(train4[0])
print(ind1,ind2)
print(train4[0][ind1][ind2])
# Out:
# 0 9
# 0.6763636363636364
# 0 4
# 0.6718181818181819
# 0 7
# 0.6818181818181818
# 0 27
# 0.6336363636363637

# %% [markdown]
# Arriba se puede observar que la red de mayor porcentaje de éxito es la que maneja Relu como función de activación. Además se observa que de todas las funciones de activación, el menor porcentaje de error se encuentra con datos de entrenamiento que no han sido blanqueados ni normalizados. Esto puede deberse a que en este caso, estos datos crudos ofrecen una mayor expresividad que el modelo aprovecha. Sin embargo, de todas maneras el porcentaje de acierto es bajo, no llega al 70% en ningún caso. Posteriormente se espera que este puntaje aumente

# %%
#Función para entrenar redes neuronales de distintas capas y distinto número de neuronas
#Para facilidad todas las capas tendrán el mismo número de neuronas
#Esta función además calcula la tasa de éxito de clasificación con los datos de validación.
#Se retorna la red y esta tasa de éxito
#Los otros parámetros de la red son similares a los del caso de una sola capa
def trainNetworkLR(learningRate,n):
    lr=0.001*10**learningRate
    clf = MLPClassifier(solver='lbfgs',batch_size=1, alpha=0,hidden_layer_sizes=(n),activation='relu', max_iter=500, learning_rate_init=lr ,random_state=1)
    clf.fit(xTrain, yTrain)   
    return [clf,clf.score(xValidation, yValidation)]

# %%
#Se itera por número de capas y número de neuronas, desde una capa hasta 7, y desde una neurona por capa hasta 30
errors=[]
neurons=[]
for i in range(-1,3):
    #Se crean arreglos temporales, cada uno corresponde a un número de capas
    errorsTemp=[None]
    neuronsTemp=[]
    for j in range(1, 30):
        #Se almacenan los resultados en los arreglos
        neuron=trainNetworkLR(i,j)
        neuronsTemp.append(neuron[0])
        errorsTemp.append(neuron[1])
    #Al final se concatenan estos arreglos temporales a los globales
    errors.append(errorsTemp)
    neurons.append(neuronsTemp)
#Se convierten a np
errors=np.array(errors)
neurons=np.array(neurons)
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:921: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# D:\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:921: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# D:\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:921: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
[ind1,ind2]=findMaxIndexes(errors)
print(ind1,ind2)
print(errors[ind1][ind2])
# Out:
# 3 9
# 0.6763636363636364

# %% [markdown]
# Se puede observar en los resultados anteriores que con una tasa de aprendizaje de 0.1 se obtuvo el modelo de mejor valor, esto es importante ya que significa que se puede utilizar esta tasa y no la que se tiene por defecto para entrenar las redes y por tanto el modelo convergería más rápido

# %%
#Función para entrenar redes neuronales de distintas capas y distinto número de neuronas
#Para facilidad todas las capas tendrán el mismo número de neuronas
#Esta función además calcula la tasa de éxito de clasificación con los datos de validación.
#Se retorna la red y esta tasa de éxito
#Los otros parámetros de la red son similares a los del caso de una sola capa
def trainNetworkLayers(nLayers,nNeurons):
    a = (nNeurons,)*nLayers
    clf = MLPClassifier(solver='lbfgs',batch_size =1, alpha=0,hidden_layer_sizes=a,activation="relu", max_iter=500, learning_rate_init=0.1, random_state=1)
    clf.fit(xTrain, yTrain)   
    return [clf,clf.score(xValidation,yValidation)]

# %%
#Se itera por número de capas y número de neuronas, desde una capa hasta 10, y desde una neurona por capa hasta 30
errorsLayers=[]
neurons2=[]
for i in range(1, 20):
    #Se crean arreglos temporales, cada uno corresponde a un número de capas
    errorsTemp=[None]
    neuronsTemp=[]
    for j in range(1, 50):
        #Se almacenan los resultados en los arreglos
        neuron=trainNetworkLayers(i,j)
        neuronsTemp.append(neuron[0])
        errorsTemp.append(neuron[1])
    #Al final se concatenan estos arreglos temporales a los globales
    errorsLayers.append(errorsTemp)
    neurons2.append(neuronsTemp)
#Se convierten a np
errorsLayers=np.array(errorsLayers)
neurons2=np.array(neurons2)
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:921: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# D:\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:921: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# D:\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:921: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
#Se utiliza el algoritmo anterior para encontrar la red de mejor resultado
[ind1,ind2]=findMaxIndexes(errorsLayers)
print(ind1,ind2)
print(errorsLayers[ind1][ind2])
# Out:
# 7 10
# 0.68

# %%
#Se le concatenan 2 None al arreglo para indicar que no se tienen valores con 0 neuronas ni 1 neurona
errorsLayers=np.concatenate(([[None]*30], errorsLayers), axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-090204fec17a> in <module>
#       1 #Se le concatenan 2 None al arreglo para indicar que no se tienen valores con 0 neuronas ni 1 neurona
# ----> 2 errorsLayers=np.concatenate(([[None]*30], errorsLayers), axis=0)
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly

# %%
#Se muestran los resultados en formato de tabla
df=pd.DataFrame(errorsLayers)
display(HTML(df.to_html()))

# %% [markdown]
# En el punto anterior se observa que la red con 4 capas ocultas (Filas) de 6 neuronas cada una (Columnas) fue la que obtuvo el mínimo error, esta tasa de éxito se observa que corresponde a 0.8183333. Esta tasa de éxito es superior a la arquitectura con solo una capa oculta, sin embargo no es significativamente superior. Es posible que los datos de input no sean suficientes para predecir completamente el género de las canciones y existan casos anómalos que hacen parte de estos que no se predijeron correctamente.

# %%
bestNN= neurons2[ind1][ind2]
#Esta red se entrena con los datos de entrenamiento totales
bestNN.fit(xTrainT, yTrainT)
#Se prueba con los datos de prueba
bestNN.score(xTest,yTest)

# %% [markdown]
# Se puede observar que la tasa de éxito de clasificación es de 0.82. Esta tasa de éxito es menor que la tasa de éxito con menos datos, esto puede deberse a que al ingresarse más datos esta arquitectura empiece a hacer un poco de overfitting y por tanto disminuya un poco el éxito. De acuerdo al cálculo anterior, se podría afirmar que con una confianza del 90% la tasa de éxito mínima es de 0.81.

# %% [markdown]
# Se puede observar que en ambos casos el error es similar para 1 capa o para multicapa. Esto significa que la red necesita de pocas capas para ajustarse lo mejor posible al modelo de acuerdo con los datos que hay. Sin embargo, se observa también que la tasa de éxito no llega a 90%, lo que significa que esta red no es capaz de clasificar 9 de cada 10 canciones correctamente pero sí 8 de cada 10 canciones en el límite inferior. Se observa que para capas con muchas neuronas, el porcentaje de éxito tiende a números bajos, cercanos a 0.5 y posteriormente a 0, es posible que el overfitting sea tal que no logra clasificar ningun dato del set de validación correctamente. El tener Relu como mejor función puede significa que los datos solo importan cuando tienen valor positivo, y cuando estos tienen valor negativo no son relevantes para el modelo
